# %%
# -*- coding: utf-8 -*-
import time
from selenium import webdriver
import os
import shutil
from pathlib import Path
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait


def processa_relatorio(browser, id_tipo_if, download_folder_path):
    ano = browser.execute_script('return document.getElementById("btnDataBase").innerText')
    ano = ano.replace("/","")
    rel = browser.execute_script('return document.getElementById("btnRelatorio").innerText')
    rel = formata_nome_relatorio(rel)
    print('Aguarda o carregamento do relatório {} - {}'.format(rel, ano))
    countdown(5)

    wait = WebDriverWait(browser, 120)
    download_link = wait.until(EC.element_to_be_clickable((By.ID, "aExportCsv")))
    download_link.click()

    print('Baixa arquivo dados.csv')
    countdown(2)

    shutil.move(
        os.path.join(os.sep,'home','rodrigo','Downloads','dados.csv'),
        os.path.join(download_folder_path, '{}_{}_{}.csv'.format(ano, id_tipo_if, rel))
    )


# retira caracteres especiais do nome do arquivo e formata nome
def formata_nome_relatorio(rel):
    rel = rel.lower()
    
    rel = rel.replace(
        'demonstração de resultado', 'demonstracao_de_resultado')
    rel = rel.replace(
        'informações de capital', 'informacoes_de_capital')
    rel = rel.replace(
        'segmentação', 'segmentacao')
    rel = rel.replace(
        'carteira de crédito ativa Pessoa Física - modalidade e prazo de vencimento',
        'carteira_credito_ativa_pf_modalidade_prazo_vencimento')
    rel = rel.replace(
        'carteira de crédito ativa Pessoa Jurídica - modalidade e prazo de vencimento',
        'carteira_credito_ativa_pj_modalidade_prazo_vencimento')
    rel = rel.replace(
        'carteira de crédito ativa Pessoa Jurídica -  por atividade econômica (cnae)',
        'carteira_credito_ativa_pj_atividade_economica_cnae')
    rel = rel.replace(
        'carteira de crédito ativa Pessoa Jurídica - por porte do tomador',
        'carteira_credito_ativa_pj_porte_tomador')
    rel = rel.replace(
        'carteira de crédito ativa - quantidade de clientes e de operações',
        'carteira_credito_ativa_pj_quantidade_clientes_operacoes')
    rel = rel.replace(
        'carteira de crédito ativa - por nível de risco da operação',
        'carteira_credito_ativa_pj_nivel_risco')
    rel = rel.replace(
        'carteira de crédito ativa - por indexador',
        'carteira_credito_ativa_por_indexador')
    rel = rel.replace(
        'Movimentação de Câmbio no Trimestre',
        'movimentacao_cambio_trimestre')

    return rel


def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timeformat = '{:02d}:{:02d}'.format(mins, secs)
        print(timeformat, end='\r')
        time.sleep(1)
        t -= 1


def get_webdriver():
    options = webdriver.ChromeOptions()
    #options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')

    browser = webdriver.Chrome('chromedriver', options=options)
    
    return browser


def prepare_download_folder(folder_name):
    download_folder_path = os.path.join('downloads', folder_name)

    if not os.path.exists(download_folder_path):
        Path(download_folder_path).mkdir(parents=True, exist_ok=True)

    return download_folder_path


def get_browser_ifdata():
    browser = get_webdriver()
    print('Acessa a página e aguarda o carregamento do combo de datas base')
    url = 'https://www3.bcb.gov.br/ifdata/index.html'
    browser.get(url)
    countdown(60)

    botao = browser.find_element_by_id('btnDataBase')
    botao.click()

    # última data disponível no combo, a partir que ela estiver visível
    # quer dizer que a página carregou completamente
    xpath = '//*[@id="ulDataBase"]/li[79]/a'
    wait = WebDriverWait(browser, 30)
    wait.until(EC.element_to_be_clickable((By.XPATH, xpath)))
    
    botao.click()

    return browser


def main(folder_name, id_tipo_if, rel_0, datas_base):
    download_folder_path = prepare_download_folder(folder_name)
    browser = get_browser_ifdata()

    # baixa todas as bases de dados (de 0 a 78 em 08/02/2020)
    for id_data_base in datas_base:
        print('Seleciona data-base')
        browser.execute_script('selectDataBase(' + str(id_data_base) + ')')
        countdown(1)

        print('Seleciona tipo instituição')
        browser.execute_script('selectTipoInst(' + str(id_tipo_if) + ')')
        countdown(1)

        # itens do relatório
        for id_tipo_relatorio in range(len(rel_0)):
            browser.execute_script('selectRelatorio(' + str(rel_0[id_tipo_relatorio]) + ')')
            processa_relatorio(browser, id_tipo_if, id_tipo_relatorio, download_folder_path)

# %%
folder_name = 'conglomerados_prudenciais'
id_tipo_if = 0
tipos_relatorios = [
    'Resumo',
    'Ativo',
    'Passivo',
    'Demonstração de Resultado',
    'Informações de Capital',
    'Segmentação',
]
datas_base = range(11, 79)

# %%
download_folder_path = prepare_download_folder(folder_name)

# %%
browser = get_browser_ifdata()
# Out:
# Acessa a página e aguarda o carregamento do combo de datas base
# 00:01

# %%
browser.implicitly_wait(10)

# baixa todas as bases de dados (de 0 a 78 em 08/02/2020)
for id_data_base in datas_base:
    print('Seleciona data-base', id_data_base)
    browser.execute_script('selectDataBase(' + str(id_data_base) + ')')
    countdown(1)

    print('Seleciona tipo instituição')
    browser.execute_script('selectTipoInst(' + str(id_tipo_if) + ')')
    countdown(1)

    # itens do relatório
    for tipo_relatorio in tipos_relatorios:
        try:
            browser.find_element_by_id('btnRelatorio').click()
            elem = browser.find_element_by_link_text(tipo_relatorio)
            elem.click()
            processa_relatorio(browser, id_tipo_if, download_folder_path)
        except:
            continue
# Out:
# Seleciona data-base 11
# Seleciona tipo instituição
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 122016
# Baixa arquivo dados.csv
# Seleciona data-base 12
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 092016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 092016
# Baixa arquivo dados.csv
# Seleciona data-base 13
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 062016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 062016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 062016
# Baixa arquivo dados.csv
# Seleciona data-base 14
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 032016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 032016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 032016
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 032016
# Baixa arquivo dados.csv
# Seleciona data-base 15
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 122015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 122015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 122015
# Baixa arquivo dados.csv
# Seleciona data-base 16
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 092015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 092015
# Baixa arquivo dados.csv
# Seleciona data-base 17
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 062015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 062015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 062015
# Baixa arquivo dados.csv
# Seleciona data-base 18
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 032015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 032015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 032015
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 032015
# Baixa arquivo dados.csv
# Seleciona data-base 19
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 122014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 122014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122014
# Baixa arquivo dados.csv
# Seleciona data-base 20
# Seleciona tipo instituição
# Aguarda o carregamento do relatório resumo - 092014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório ativo - 092014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092014
# Baixa arquivo dados.csv
# Seleciona data-base 21
# Seleciona tipo instituição
# Aguarda o carregamento do relatório resumo - 062014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório ativo - 062014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 062014
# Baixa arquivo dados.csv
# Seleciona data-base 22
# Seleciona tipo instituição
# Aguarda o carregamento do relatório resumo - 032014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório ativo - 032014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 032014
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 032014
# Baixa arquivo dados.csv
# Seleciona data-base 23
# Seleciona tipo instituição
# Aguarda o carregamento do relatório resumo - 122013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório ativo - 122013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 122013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 122013
# Baixa arquivo dados.csv
# Seleciona data-base 24
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 092013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 092013
# Baixa arquivo dados.csv
# Seleciona data-base 25
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 062013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 062013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 062013
# Baixa arquivo dados.csv
# Seleciona data-base 26
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 032013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 032013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 032013
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 032013
# Baixa arquivo dados.csv
# Seleciona data-base 27
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 122012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 122012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 122012
# Baixa arquivo dados.csv
# Seleciona data-base 28
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 092012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 092012
# Baixa arquivo dados.csv
# Seleciona data-base 29
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 062012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 062012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 062012
# Baixa arquivo dados.csv
# Seleciona data-base 30
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 032012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 032012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 032012
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 032012
# Baixa arquivo dados.csv
# Seleciona data-base 31
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 122011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 122011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 122011
# Baixa arquivo dados.csv
# Seleciona data-base 32
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 092011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 092011
# Baixa arquivo dados.csv
# Seleciona data-base 33
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 062011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 062011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 062011
# Baixa arquivo dados.csv
# Seleciona data-base 34
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 032011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 032011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 032011
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 032011
# Baixa arquivo dados.csv
# Seleciona data-base 35
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 122010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 122010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 122010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 122010
# Baixa arquivo dados.csv
# Seleciona data-base 36
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 092010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 092010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório demonstracao_de_resultado - 092010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório informacoes_de_capital - 092010
# Baixa arquivo dados.csv
# Seleciona data-base 37
# Seleciona tipo instituição
# Aguarda o carregamento do relatório ativo - 062010
# Baixa arquivo dados.csv
# Aguarda o carregamento do relatório passivo - 062010
# 00:01
