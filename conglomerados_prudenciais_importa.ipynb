# %%
import os
import shutil
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://usr_5482:usr_5482@10.4.2.240:5432/5482_4', echo=True)

# %%
file_name = 'prudenciais_resumo_relatorios.csv'
df = pd.read_csv(os.path.join('bases', file_name))
df.columns
df.head()

# remove unnamed columns
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 20', axis=1, inplace=True)
df.drop('Unnamed: 17', axis=1, inplace=True)

a_renomear = {
    'Instituição financeira':'nome_if',
    'Código':'co_if',
    'TCB':'tp_consolidado_bancario',
    'SR':'segmento',
    'TD':'tp_consolidacao',
    'TC':'tp_controle',
    'Cidade':'cidade',
    'UF':'uf',
    'Data':'dt_base',
    'Ativo Total':'ativo_total',
    'Carteira de Crédito Classificada':'carteira_credito_classificada',
    'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros':'passivo_circulante_exigivel_longo_prazo',
    'Captações':'captacoes',
    'Patrimônio Líquido':'patrimonio_liquido',
    'Lucro Líquido':'lucro_liquido',
    'Patrimônio de Referência para Comparação com o RWA':'patrimonio_referencia',
    'Índice de Basileia':'ic_basileia',
    'Índice de Imobilização':'ic_imobilizacao',
    'Número de Agências':'nu_agencias',
    'Número de Postos de Atendimento':'nu_postos_atendimento',
}

# renomeia as colunas
df = df.rename(columns=a_renomear)

# remove informações que são consolidadas
df = df[df['co_if'].notnull()]

# convert just columns "a" and "b"
df['co_if'] = df['co_if'].astype(int)
df['tp_controle'] = df['tp_controle'].astype(int)

print(df.head())
print(df.dtypes)

# salva os registros no banco de dados
df.to_sql('prudenciais_resumo_relatorios_import', con=engine, if_exists='replace')

# executa para ver os resultados retornados que foram importados
df_banco = engine.execute("SELECT * FROM prudenciais_resumo_relatorios_import").fetchall()
print(len(df_banco))

print('Registros importados com sucesso.')
# Out:
#                                              nome_if     co_if  \
# 0                                                 BB     49906
# 1                                               ITAU     10069
# 2                            CAIXA ECONOMICA FEDERAL    360305
# 3                                           BRADESCO     10045
# 4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...  33657248
#
#   tp_consolidado_bancario segmento tp_consolidacao  tp_controle  \
# 0                      b1      NaN               C            1
# 1                      b1      NaN               C            2
# 2                      b1      NaN               I            1
# 3                      b1      NaN               C            2
# 4                      b4      NaN               I            1
#
#            cidade  uf  dt_base    ativo_total carteira_credito_classificada  \
# 0        BRASILIA  DF  12/2013  1.175.217.453                   601.103.432
# 1       SAO PAULO  SP  12/2013  1.027.324.008                   412.149.086
# 2        BRASILIA  DF  12/2013    858.475.356                   494.237.081
# 3          OSASCO  SP  12/2013    776.724.294                   322.615.977
# 4  RIO DE JANEIRO  RJ  12/2013    762.953.109                   280.645.850
#
#   passivo_circulante_exigivel_longo_prazo    captacoes patrimonio_liquido  \
# 0                           1.104.680.241  924.558.001         70.537.212
# 1                             938.357.806  721.811.639         88.966.202
# 2                             831.101.993  723.006.685         27.373.363
# 3                             705.588.304  600.199.112         71.135.989
# 4                             717.326.958  488.690.099         45.626.151
#
#   lucro_liquido patrimonio_referencia ic_basileia ic_imobilizacao nu_agencias  \
# 0     5.881.780           118.234.351      14,54%          23,47%       5.455
# 1     7.770.988           125.143.549      16,45%          49,92%       3.999
# 2     3.582.770            71.440.993      15,13%          12,85%       3.289
# 3     6.151.489            95.803.662      16,61%          45,38%       4.704
# 4     4.888.773           108.669.482      19,21%          40,91%           4
#
#   nu_postos_atendimento
# 0                 1.554
# 1                   890
# 2                   725
# 3                 1.423
# 4                     0
# nome_if                                    object
# co_if                                       int32
# tp_consolidado_bancario                    object
# segmento                                   object
# tp_consolidacao                            object
# tp_controle                                 int32
# cidade                                     object
# uf                                         object
# dt_base                                    object
# ativo_total                                object
# carteira_credito_classificada              object
# passivo_circulante_exigivel_longo_prazo    object
# captacoes                                  object
# patrimonio_liquido                         object
# lucro_liquido                              object
# patrimonio_referencia                      object
# ic_basileia                                object
# ic_imobilizacao                            object
# nu_agencias                                object
# nu_postos_atendimento                      object
# dtype: object
# 2020-02-11 12:19:50,990 INFO sqlalchemy.engine.base.Engine select version()
# 2020-02-11 12:19:50,992 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:50,996 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-02-11 12:19:50,997 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:51,002 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-02-11 12:19:51,003 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:51,006 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-02-11 12:19:51,008 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:51,012 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-02-11 12:19:51,014 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:51,019 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-02-11 12:19:51,021 INFO sqlalchemy.engine.base.Engine {'name': 'prudenciais_resumo_relatorios_import'}
# 2020-02-11 12:19:51,029 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE prudenciais_resumo_relatorios_import (
# 	index BIGINT,
# 	nome_if TEXT,
# 	co_if INTEGER,
# 	tp_consolidado_bancario TEXT,
# 	segmento TEXT,
# 	tp_consolidacao TEXT,
# 	tp_controle INTEGER,
# 	cidade TEXT,
# 	uf TEXT,
# 	dt_base TEXT,
# 	ativo_total TEXT,
# 	carteira_credito_classificada TEXT,
# 	passivo_circulante_exigivel_longo_prazo TEXT,
# 	captacoes TEXT,
# 	patrimonio_liquido TEXT,
# 	lucro_liquido TEXT,
# 	patrimonio_referencia TEXT,
# 	ic_basileia TEXT,
# 	ic_imobilizacao TEXT,
# 	nu_agencias TEXT,
# 	nu_postos_atendimento TEXT
# )
#
#
# 2020-02-11 12:19:51,031 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:51,042 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:19:51,047 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_prudenciais_resumo_relatorios_import_index ON prudenciais_resumo_relatorios_import (index)
# 2020-02-11 12:19:51,050 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:19:51,056 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:19:51,129 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-02-11 12:19:52,178 INFO sqlalchemy.engine.base.Engine INSERT INTO prudenciais_resumo_relatorios_import (index, nome_if, co_if, tp_consolidado_bancario, segmento, tp_consolidacao, tp_controle, cidade, uf, dt_base, ativo_total, carteira_credito_classificada, passivo_circulante_exigivel_longo_prazo, captacoes, patrimonio_liquido, lucro_liquido, patrimonio_referencia, ic_basileia, ic_imobilizacao, nu_agencias, nu_postos_atendimento) VALUES (%(index)s, %(nome_if)s, %(co_if)s, %(tp_consolidado_bancario)s, %(segmento)s, %(tp_consolidacao)s, %(tp_controle)s, %(cidade)s, %(uf)s, %(dt_base)s, %(ativo_total)s, %(carteira_credito_classificada)s, %(passivo_circulante_exigivel_longo_prazo)s, %(captacoes)s, %(patrimonio_liquido)s, %(lucro_liquido)s, %(patrimonio_referencia)s, %(ic_basileia)s, %(ic_imobilizacao)s, %(nu_agencias)s, %(nu_postos_atendimento)s)
# 2020-02-11 12:19:52,179 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'nome_if': 'BB', 'co_if': 49906, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '12/2013', 'ativo_total': '1.175.217.453', 'carteira_credito_classificada': '601.103.432', 'passivo_circulante_exigivel_longo_prazo': '1.104.680.241', 'captacoes': '924.558.001', 'patrimonio_liquido': '70.537.212', 'lucro_liquido': '5.881.780', 'patrimonio_referencia': '118.234.351', 'ic_basileia': '14,54%', 'ic_imobilizacao': '23,47%', 'nu_agencias': '5.455', 'nu_postos_atendimento': '1.554'}, {'index': 1, 'nome_if': 'ITAU', 'co_if': 10069, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '12/2013', 'ativo_total': '1.027.324.008', 'carteira_credito_classificada': '412.149.086', 'passivo_circulante_exigivel_longo_prazo': '938.357.806', 'captacoes': '721.811.639', 'patrimonio_liquido': '88.966.202', 'lucro_liquido': '7.770.988', 'patrimonio_referencia': '125.143.549', 'ic_basileia': '16,45%', 'ic_imobilizacao': '49,92%', 'nu_agencias': '3.999', 'nu_postos_atendimento': '890'}, {'index': 2, 'nome_if': 'CAIXA ECONOMICA FEDERAL', 'co_if': 360305, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'I', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '12/2013', 'ativo_total': '858.475.356', 'carteira_credito_classificada': '494.237.081', 'passivo_circulante_exigivel_longo_prazo': '831.101.993', 'captacoes': '723.006.685', 'patrimonio_liquido': '27.373.363', 'lucro_liquido': '3.582.770', 'patrimonio_referencia': '71.440.993', 'ic_basileia': '15,13%', 'ic_imobilizacao': '12,85%', 'nu_agencias': '3.289', 'nu_postos_atendimento': '725'}, {'index': 3, 'nome_if': 'BRADESCO', 'co_if': 10045, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'OSASCO', 'uf': 'SP', 'dt_base': '12/2013', 'ativo_total': '776.724.294', 'carteira_credito_classificada': '322.615.977', 'passivo_circulante_exigivel_longo_prazo': '705.588.304', 'captacoes': '600.199.112', 'patrimonio_liquido': '71.135.989', 'lucro_liquido': '6.151.489', 'patrimonio_referencia': '95.803.662', 'ic_basileia': '16,61%', 'ic_imobilizacao': '45,38%', 'nu_agencias': '4.704', 'nu_postos_atendimento': '1.423'}, {'index': 4, 'nome_if': 'BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E SOCIAL', 'co_if': 33657248, 'tp_consolidado_bancario': 'b4', 'segmento': None, 'tp_consolidacao': 'I', 'tp_controle': 1, 'cidade': 'RIO DE JANEIRO', 'uf': 'RJ', 'dt_base': '12/2013', 'ativo_total': '762.953.109', 'carteira_credito_classificada': '280.645.850', 'passivo_circulante_exigivel_longo_prazo': '717.326.958', 'captacoes': '488.690.099', 'patrimonio_liquido': '45.626.151', 'lucro_liquido': '4.888.773', 'patrimonio_referencia': '108.669.482', 'ic_basileia': '19,21%', 'ic_imobilizacao': '40,91%', 'nu_agencias': '4', 'nu_postos_atendimento': '0'}, {'index': 5, 'nome_if': 'SANTANDER', 'co_if': 30379, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 3, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '12/2013', 'ativo_total': '495.443.913', 'carteira_credito_classificada': '227.350.030', 'passivo_circulante_exigivel_longo_prazo': '431.682.956', 'captacoes': '316.679.112', 'patrimonio_liquido': '63.760.958', 'lucro_liquido': '1.075.564', 'patrimonio_referencia': '66.187.323', 'ic_basileia': '19,19%', 'ic_imobilizacao': '29,96%', 'nu_agencias': '2.763', 'nu_postos_atendimento': '1.258'}, {'index': 6, 'nome_if': 'HSBC', 'co_if': 51152, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 3, 'cidade': 'CURITIBA', 'uf': 'PR', 'dt_base': '12/2013', 'ativo_total': '159.948.239', 'carteira_credito_classificada': '62.532.550', 'passivo_circulante_exigivel_longo_prazo': '149.939.207', 'captacoes': '99.830.381', 'patrimonio_liquido': '10. ...
# 2020-02-11 12:20:49,188 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:20:49,203 INFO sqlalchemy.engine.base.Engine SELECT * FROM prudenciais_resumo_relatorios_import
# 2020-02-11 12:20:49,205 INFO sqlalchemy.engine.base.Engine {}
# Registros importados com sucesso.

# %%
file_name = 'prudenciais_ativo_relatorios.csv'
df = pd.read_csv(os.path.join('bases', file_name), low_memory=False)
print(df.columns)

# remove unnamed columns
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 26', axis=1, inplace=True)

a_renomear = {
    'Instituição financeira':'nome_if',
    'Código':'co_if',
    'TCB':'tp_consolidado_bancario',
    'SR':'segmento',
    'TD':'tp_consolidacao',
    'TC':'tp_controle',
    'Cidade':'cidade',
    'UF':'uf',
    'Data':'dt_base',
    'Disponibilidades (a)':'disponibilidades',
    'Aplicações Interfinanceiras de Liquidez (b)':'aplicacoes_interfinanceiras_liquidez',
    'TVM e Instrumentos Financeiros Derivativos (c)':'tvm_derivativos',
    'Operações de Crédito':'operacoes_credito',    
    'Unnamed: 13':'provisao_operacoes_credito',
    'Unnamed: 14':'operacoes_credito_liquidas_provisao',
    'Arrendamento Mercantil':'arrendamento_mercantil_receber',
    'Unnamed: 16':'imobilizado_de_arrendamento',
    'Unnamed: 17':'credores_antecipacao_valor_residual',
    'Unnamed: 18':'provisao_sobre_arrendamento_mercantil',
    'Unnamed: 19':'arrendamento_mercantil_liquido_provisao',
    'Outros Créditos - Líquido de Provisão (f)':'outros_creditos_liquidos_provisao',
    'Outros Ativos Realizáveis (g)':'outros_ativos_realizaveis',
    'Permanente Ajustado (h)':'permanente_ajustado',
    'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)':'ativo_total_ajustado',
    'Credores por Antecipação de Valor Residual (j)':'credores_antecipacao_valor_residual',
    'Ativo Total (k) = (i) - (j)':'ativo_total'
}

# renomeia as colunas
df = df.rename(columns=a_renomear)

# remove informações que são consolidadas
df = df[df['co_if'].notnull()]

# convert just columns "a" and "b"
df['co_if'] = df['co_if'].astype(int)
df['tp_controle'] = df['tp_controle'].astype(int)

print(df.head())
print(df.dtypes)

# salva os registros no banco de dados
df.to_sql('prudenciais_ativo_relatorios_import', con=engine, if_exists='replace')

# executa para ver os resultados retornados que foram importados
df_banco = engine.execute("SELECT * FROM prudenciais_ativo_relatorios_import").fetchall()
print(len(df_banco))

print('Registros importados com sucesso.')
# Out:
# Index(['Unnamed: 0', 'Instituição financeira', 'Código', 'TCB', 'SR', 'TD',
#        'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)',
#        'Aplicações Interfinanceiras de Liquidez (b)',
#        'TVM e Instrumentos Financeiros Derivativos (c)',
#        'Operações de Crédito', 'Unnamed: 13', 'Unnamed: 14',
#        'Arrendamento Mercantil', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Outros Créditos - Líquido de Provisão (f)',
#        'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)',
#        'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)',
#        'Credores por Antecipação de Valor Residual (j)',
#        'Ativo Total (k) = (i) - (j)', 'Unnamed: 26'],
#       dtype='object')
#                                              nome_if     co_if  \
# 1                                                 BB     49906
# 2                                               ITAU     10069
# 3                                           BRADESCO     10045
# 4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...  33657248
# 5                            CAIXA ECONOMICA FEDERAL    360305
#
#   tp_consolidado_bancario segmento tp_consolidacao  tp_controle  \
# 1                      b1      NaN               C            1
# 2                      b1      NaN               C            2
# 3                      b1      NaN               C            2
# 4                      b4      NaN               I            1
# 5                      b1      NaN               I            1
#
#            cidade  uf  dt_base disponibilidades  ...  \
# 1        BRASILIA  DF  03/2010        7.116.688  ...
# 2       SAO PAULO  SP  03/2010        9.284.245  ...
# 3          OSASCO  SP  03/2010        8.632.592  ...
# 4  RIO DE JANEIRO  RJ  03/2010            3.306  ...
# 5        BRASILIA  DF  03/2010        2.898.005  ...
#
#   imobilizado_de_arrendamento credores_antecipacao_valor_residual  \
# 1                   5.145.685                           2.347.610
# 2                  83.843.772                          40.999.414
# 3                  35.029.434                          15.096.641
# 4                           0                                   0
# 5                           0                                   0
#
#   provisao_sobre_arrendamento_mercantil  \
# 1                              -200.555
# 2                            -2.655.902
# 3                            -1.680.997
# 4                                     0
# 5                                     0
#
#   arrendamento_mercantil_liquido_provisao outros_creditos_liquidos_provisao  \
# 1                               7.334.091                        91.722.017
# 2                             124.964.596                        85.579.093
# 3                              48.661.428                        52.880.126
# 4                                       0                         5.609.316
# 5                                       0                        18.134.406
#
#   outros_ativos_realizaveis permanente_ajustado ativo_total_ajustado  \
# 1                54.142.962          25.185.932          665.844.012
# 2                40.305.437          25.713.936          652.484.577
# 3                40.201.453          26.800.496          486.560.570
# 4               137.080.149          44.124.687          383.416.042
# 5                68.893.174           5.314.578          364.315.306
#
#   credores_antecipacao_valor_residual  ativo_total
# 1                           2.347.610  663.496.402
# 2                          40.999.414  611.485.163
# 3                          15.096.641  471.463.929
# 4                                   0  383.416.042
# 5                                   0  364.315.306
#
# [5 rows x 26 columns]
# nome_if                                    object
# co_if                                       int32
# tp_consolidado_bancario                    object
# segmento                                   object
# tp_consolidacao                            object
# tp_controle                                 int32
# cidade                                     object
# uf                                         object
# dt_base                                    object
# disponibilidades                           object
# aplicacoes_interfinanceiras_liquidez       object
# tvm_derivativos                            object
# operacoes_credito                          object
# provisao_operacoes_credito                 object
# operacoes_credito_liquidas_provisao        object
# arrendamento_mercantil_receber             object
# imobilizado_de_arrendamento                object
# credores_antecipacao_valor_residual        object
# provisao_sobre_arrendamento_mercantil      object
# arrendamento_mercantil_liquido_provisao    object
# outros_creditos_liquidos_provisao          object
# outros_ativos_realizaveis                  object
# permanente_ajustado                        object
# ativo_total_ajustado                       object
# credores_antecipacao_valor_residual        object
# ativo_total                                object
# dtype: object
# 2020-02-11 12:26:32,858 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-02-11 12:26:32,859 INFO sqlalchemy.engine.base.Engine {'name': 'prudenciais_ativo_relatorios_import'}
# 2020-02-11 12:26:32,872 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE prudenciais_ativo_relatorios_import (
# 	index BIGINT,
# 	nome_if TEXT,
# 	co_if INTEGER,
# 	tp_consolidado_bancario TEXT,
# 	segmento TEXT,
# 	tp_consolidacao TEXT,
# 	tp_controle INTEGER,
# 	cidade TEXT,
# 	uf TEXT,
# 	dt_base TEXT,
# 	disponibilidades TEXT,
# 	aplicacoes_interfinanceiras_liquidez TEXT,
# 	tvm_derivativos TEXT,
# 	operacoes_credito TEXT,
# 	provisao_operacoes_credito TEXT,
# 	operacoes_credito_liquidas_provisao TEXT,
# 	arrendamento_mercantil_receber TEXT,
# 	imobilizado_de_arrendamento TEXT,
# 	credores_antecipacao_valor_residual TEXT,
# 	provisao_sobre_arrendamento_mercantil TEXT,
# 	arrendamento_mercantil_liquido_provisao TEXT,
# 	outros_creditos_liquidos_provisao TEXT,
# 	outros_ativos_realizaveis TEXT,
# 	permanente_ajustado TEXT,
# 	ativo_total_ajustado TEXT,
# 	ativo_total TEXT
# )
#
#
# 2020-02-11 12:26:32,875 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:26:32,886 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:26:32,891 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_prudenciais_ativo_relatorios_import_index ON prudenciais_ativo_relatorios_import (index)
# 2020-02-11 12:26:32,894 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:26:32,900 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:26:33,031 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-02-11 12:26:35,145 INFO sqlalchemy.engine.base.Engine INSERT INTO prudenciais_ativo_relatorios_import (index, nome_if, co_if, tp_consolidado_bancario, segmento, tp_consolidacao, tp_controle, cidade, uf, dt_base, disponibilidades, aplicacoes_interfinanceiras_liquidez, tvm_derivativos, operacoes_credito, provisao_operacoes_credito, operacoes_credito_liquidas_provisao, arrendamento_mercantil_receber, imobilizado_de_arrendamento, credores_antecipacao_valor_residual, provisao_sobre_arrendamento_mercantil, arrendamento_mercantil_liquido_provisao, outros_creditos_liquidos_provisao, outros_ativos_realizaveis, permanente_ajustado, ativo_total_ajustado, ativo_total) VALUES (%(index)s, %(nome_if)s, %(co_if)s, %(tp_consolidado_bancario)s, %(segmento)s, %(tp_consolidacao)s, %(tp_controle)s, %(cidade)s, %(uf)s, %(dt_base)s, %(disponibilidades)s, %(aplicacoes_interfinanceiras_liquidez)s, %(tvm_derivativos)s, %(operacoes_credito)s, %(provisao_operacoes_credito)s, %(operacoes_credito_liquidas_provisao)s, %(arrendamento_mercantil_receber)s, %(imobilizado_de_arrendamento)s, %(credores_antecipacao_valor_residual)s, %(provisao_sobre_arrendamento_mercantil)s, %(arrendamento_mercantil_liquido_provisao)s, %(outros_creditos_liquidos_provisao)s, %(outros_ativos_realizaveis)s, %(permanente_ajustado)s, %(ativo_total_ajustado)s, %(ativo_total)s)
# 2020-02-11 12:26:35,147 INFO sqlalchemy.engine.base.Engine ({'index': 1, 'nome_if': 'BB', 'co_if': 49906, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '03/2010', 'disponibilidades': '7.116.688', 'aplicacoes_interfinanceiras_liquidez': '145.928.145', 'tvm_derivativos': '86.601.285', 'operacoes_credito': '264.549.229', 'provisao_operacoes_credito': '-16.736.337', 'operacoes_credito_liquidas_provisao': '247.812.892', 'arrendamento_mercantil_receber': '41.350', 'imobilizado_de_arrendamento': '5.145.685', 'credores_antecipacao_valor_residual': '2.347.610', 'provisao_sobre_arrendamento_mercantil': '-200.555', 'arrendamento_mercantil_liquido_provisao': '7.334.091', 'outros_creditos_liquidos_provisao': '91.722.017', 'outros_ativos_realizaveis': '54.142.962', 'permanente_ajustado': '25.185.932', 'ativo_total_ajustado': '665.844.012', 'ativo_total': '663.496.402'}, {'index': 2, 'nome_if': 'ITAU', 'co_if': 10069, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '03/2010', 'disponibilidades': '9.284.245', 'aplicacoes_interfinanceiras_liquidez': '128.878.340', 'tvm_derivativos': '72.446.067', 'operacoes_credito': '185.040.243', 'provisao_operacoes_credito': '-19.727.380', 'operacoes_credito_liquidas_provisao': '165.312.863', 'arrendamento_mercantil_receber': '2.777.312', 'imobilizado_de_arrendamento': '83.843.772', 'credores_antecipacao_valor_residual': '40.999.414', 'provisao_sobre_arrendamento_mercantil': '-2.655.902', 'arrendamento_mercantil_liquido_provisao': '124.964.596', 'outros_creditos_liquidos_provisao': '85.579.093', 'outros_ativos_realizaveis': '40.305.437', 'permanente_ajustado': '25.713.936', 'ativo_total_ajustado': '652.484.577', 'ativo_total': '611.485.163'}, {'index': 3, 'nome_if': 'BRADESCO', 'co_if': 10045, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'OSASCO', 'uf': 'SP', 'dt_base': '03/2010', 'disponibilidades': '8.632.592', 'aplicacoes_interfinanceiras_liquidez': '97.087.237', 'tvm_derivativos': '64.422.368', 'operacoes_credito': '161.261.416', 'provisao_operacoes_credito': '-13.386.545', 'operacoes_credito_liquidas_provisao': '147.874.871', 'arrendamento_mercantil_receber': '216.351', 'imobilizado_de_arrendamento': '35.029.434', 'credores_antecipacao_valor_residual': '15.096.641', 'provisao_sobre_arrendamento_mercantil': '-1.680.997', 'arrendamento_mercantil_liquido_provisao': '48.661.428', 'outros_creditos_liquidos_provisao': '52.880.126', 'outros_ativos_realizaveis': '40.201.453', 'permanente_ajustado': '26.800.496', 'ativo_total_ajustado': '486.560.570', 'ativo_total': '471.463.929'}, {'index': 4, 'nome_if': 'BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E SOCIAL', 'co_if': 33657248, 'tp_consolidado_bancario': 'b4', 'segmento': None, 'tp_consolidacao': 'I', 'tp_controle': 1, 'cidade': 'RIO DE JANEIRO', 'uf': 'RJ', 'dt_base': '03/2010', 'disponibilidades': '3.306', 'aplicacoes_interfinanceiras_liquidez': '1.431.439', 'tvm_derivativos': '38.493.383', 'operacoes_credito': '159.973.500', 'provisao_operacoes_credito': '-3.299.739', 'operacoes_credito_liquidas_provisao': '156.673.761', 'arrendamento_mercantil_receber': '0', 'imobilizado_de_arrendamento': '0', 'credores_antecipacao_valor_residual': '0', 'provisao_sobre_arrendamento_mercantil': '0', 'arrendamento_mercantil_liquido_provisao': '0', 'outros_creditos_liquidos_provisao': '5.609.316', 'outros_ativos_realizaveis': '137.080.149', 'permanente_ajustado': '44.124.687', 'ativo_total_ajustado': '383.416.042', 'ativo_total': '383.416.042'}, {'index': 5, 'nome_if': 'CAIXA ECONOMICA FEDERAL', 'co_if': 360305, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'I', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '03/2010', 'disponibilidades': '2.898.005', 'aplicacoes_interfinanceiras_liquidez': '38.505.3 ...
# 2020-02-11 12:28:16,701 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:28:16,718 INFO sqlalchemy.engine.base.Engine SELECT * FROM prudenciais_ativo_relatorios_import
# 2020-02-11 12:28:16,720 INFO sqlalchemy.engine.base.Engine {}
# Registros importados com sucesso.

# %%
file_name = 'prudenciais_passivo_relatorios.csv'
df = pd.read_csv(os.path.join('bases', file_name), low_memory=False)

# remove unnamed columns
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 30', axis=1, inplace=True)

a_renomear = {
    'Instituição financeira':'nome_if',
    'Código':'co_if',
    'TCB':'tp_consolidado_bancario',
    'SR':'segmento',
    'TD':'tp_consolidacao',
    'TC':'tp_controle',
    'Cidade':'cidade',
    'UF':'uf',
    'Data':'dt_base',
    'Captações':'depositos_vista',
    'Unnamed: 10':'depositos_poupanca',
    'Unnamed: 11':'depositos_interfinanceiros',
    'Unnamed: 12':'depositos_prazo',
    'Unnamed: 13':'outros_depositos',
    'Unnamed: 14':'deposito_total',
    'Unnamed: 15':'obrigacoes_operacoes_compromissadas',
    'Unnamed: 16':'letras_credito_imobiliario',
    'Unnamed: 17':'letras_credito_agronegocio',
    'Unnamed: 18':'letras_financeiras',
    'Unnamed: 19':'obrigacoes_titulos_valores_mobiliarios_exterior',
    'Unnamed: 20':'outros_recursos_aceites_emissao_titulos',
    'Unnamed: 21':'recursos_aceites_emissao_titulos',
    'Unnamed: 22':'obrigacoes_emprestimos_repasses',
    'Unnamed: 23':'captacoes',
    'Instrumentos Derivativos (f)':'instrumentos_derivativos',
    'Outras Obrigações (g)':'outras_obrigacoes',
    'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)':'passivo_circulante_exigivel_longo_prazo',
    'Resultados de Exercícios Futuros (i)':'resultado_exercicios_futuros',
    'Patrimônio Líquido (j)':'patrimonio_liquido',
    'Passivo Total (k) = (h) + (i) + (j)':'passivo_total'
}

# renomeia as colunas
df = df.rename(columns=a_renomear)

# remove informações que são consolidadas
df = df[df['co_if'].notnull()]

# convert just columns "a" and "b"
df['co_if'] = df['co_if'].astype(int)
df['tp_controle'] = df['tp_controle'].astype(int)

print(df.head())
print(df.dtypes)

# salva os registros no banco de dados
df.to_sql('prudenciais_passivo_relatorios_import', con=engine, if_exists='replace')

# executa para ver os resultados retornados que foram importados
df_banco = engine.execute("SELECT * FROM prudenciais_passivo_relatorios_import").fetchall()
print(len(df_banco))

print('Registros importados com sucesso.')
# Out:
#                                              nome_if     co_if  \
# 2                                                 BB     49906
# 3                                               ITAU     10069
# 4                                           BRADESCO     10045
# 5  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...  33657248
# 6                            CAIXA ECONOMICA FEDERAL    360305
#
#   tp_consolidado_bancario segmento tp_consolidacao  tp_controle  \
# 2                      b1      NaN               C            1
# 3                      b1      NaN               C            2
# 4                      b1      NaN               C            2
# 5                      b4      NaN               I            1
# 6                      b1      NaN               I            1
#
#            cidade  uf  dt_base depositos_vista  ...  \
# 2        BRASILIA  DF  06/2010      56.970.965  ...
# 3       SAO PAULO  SP  06/2010      28.676.985  ...
# 4          OSASCO  SP  06/2010      32.901.702  ...
# 5  RIO DE JANEIRO  RJ  06/2010               0  ...
# 6        BRASILIA  DF  06/2010      17.991.400  ...
#
#   outros_recursos_aceites_emissao_titulos recursos_aceites_emissao_titulos  \
# 2                                       0                        7.005.315
# 3                               1.022.148                       16.797.659
# 4                               1.737.751                       12.729.362
# 5                                       0                                0
# 6                                 511.127                        5.832.596
#
#   obrigacoes_emprestimos_repasses    captacoes instrumentos_derivativos  \
# 2                      43.483.438  534.489.331                1.197.683
# 3                      36.638.845  414.698.014                6.926.313
# 4                      35.035.325  363.937.482                1.102.955
# 5                     247.635.396  279.503.359                  187.154
# 6                      49.351.946  319.656.774                    1.598
#
#   outras_obrigacoes passivo_circulante_exigivel_longo_prazo  \
# 2       108.624.671                             644.311.684
# 3       152.108.297                             573.732.624
# 4        85.871.490                             450.911.927
# 5       153.029.805                             432.720.319
# 6        47.284.355                             366.942.727
#
#   resultado_exercicios_futuros patrimonio_liquido passivo_total
# 2                      209.940         39.386.785   683.908.409
# 3                      157.633         56.027.775   629.918.032
# 4                      250.972         44.459.353   495.622.252
# 5                            0         30.580.104   463.300.423
# 6                            0         14.295.214   381.237.941
#
# [5 rows x 30 columns]
# nome_if                                            object
# co_if                                               int32
# tp_consolidado_bancario                            object
# segmento                                           object
# tp_consolidacao                                    object
# tp_controle                                         int32
# cidade                                             object
# uf                                                 object
# dt_base                                            object
# depositos_vista                                    object
# depositos_poupanca                                 object
# depositos_interfinanceiros                         object
# depositos_prazo                                    object
# outros_depositos                                   object
# deposito_total                                     object
# obrigacoes_operacoes_compromissadas                object
# letras_credito_imobiliario                         object
# letras_credito_agronegocio                         object
# letras_financeiras                                 object
# obrigacoes_titulos_valores_mobiliarios_exterior    object
# outros_recursos_aceites_emissao_titulos            object
# recursos_aceites_emissao_titulos                   object
# obrigacoes_emprestimos_repasses                    object
# captacoes                                          object
# instrumentos_derivativos                           object
# outras_obrigacoes                                  object
# passivo_circulante_exigivel_longo_prazo            object
# resultado_exercicios_futuros                       object
# patrimonio_liquido                                 object
# passivo_total                                      object
# dtype: object
# 2020-02-11 12:39:35,589 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-02-11 12:39:35,591 INFO sqlalchemy.engine.base.Engine {'name': 'prudenciais_passivo_relatorios_import'}
# 2020-02-11 12:39:35,602 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE prudenciais_passivo_relatorios_import (
# 	index BIGINT,
# 	nome_if TEXT,
# 	co_if INTEGER,
# 	tp_consolidado_bancario TEXT,
# 	segmento TEXT,
# 	tp_consolidacao TEXT,
# 	tp_controle INTEGER,
# 	cidade TEXT,
# 	uf TEXT,
# 	dt_base TEXT,
# 	depositos_vista TEXT,
# 	depositos_poupanca TEXT,
# 	depositos_interfinanceiros TEXT,
# 	depositos_prazo TEXT,
# 	outros_depositos TEXT,
# 	deposito_total TEXT,
# 	obrigacoes_operacoes_compromissadas TEXT,
# 	letras_credito_imobiliario TEXT,
# 	letras_credito_agronegocio TEXT,
# 	letras_financeiras TEXT,
# 	obrigacoes_titulos_valores_mobiliarios_exterior TEXT,
# 	outros_recursos_aceites_emissao_titulos TEXT,
# 	recursos_aceites_emissao_titulos TEXT,
# 	obrigacoes_emprestimos_repasses TEXT,
# 	captacoes TEXT,
# 	instrumentos_derivativos TEXT,
# 	outras_obrigacoes TEXT,
# 	passivo_circulante_exigivel_longo_prazo TEXT,
# 	resultado_exercicios_futuros TEXT,
# 	patrimonio_liquido TEXT,
# 	passivo_total TEXT
# )
#
#
# 2020-02-11 12:39:35,603 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:39:35,613 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:39:35,648 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_prudenciais_passivo_relatorios_import_index ON prudenciais_passivo_relatorios_import (index)
# 2020-02-11 12:39:35,648 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:39:35,658 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:39:35,792 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-02-11 12:39:38,180 INFO sqlalchemy.engine.base.Engine INSERT INTO prudenciais_passivo_relatorios_import (index, nome_if, co_if, tp_consolidado_bancario, segmento, tp_consolidacao, tp_controle, cidade, uf, dt_base, depositos_vista, depositos_poupanca, depositos_interfinanceiros, depositos_prazo, outros_depositos, deposito_total, obrigacoes_operacoes_compromissadas, letras_credito_imobiliario, letras_credito_agronegocio, letras_financeiras, obrigacoes_titulos_valores_mobiliarios_exterior, outros_recursos_aceites_emissao_titulos, recursos_aceites_emissao_titulos, obrigacoes_emprestimos_repasses, captacoes, instrumentos_derivativos, outras_obrigacoes, passivo_circulante_exigivel_longo_prazo, resultado_exercicios_futuros, patrimonio_liquido, passivo_total) VALUES (%(index)s, %(nome_if)s, %(co_if)s, %(tp_consolidado_bancario)s, %(segmento)s, %(tp_consolidacao)s, %(tp_controle)s, %(cidade)s, %(uf)s, %(dt_base)s, %(depositos_vista)s, %(depositos_poupanca)s, %(depositos_interfinanceiros)s, %(depositos_prazo)s, %(outros_depositos)s, %(deposito_total)s, %(obrigacoes_operacoes_compromissadas)s, %(letras_credito_imobiliario)s, %(letras_credito_agronegocio)s, %(letras_financeiras)s, %(obrigacoes_titulos_valores_mobiliarios_exterior)s, %(outros_recursos_aceites_emissao_titulos)s, %(recursos_aceites_emissao_titulos)s, %(obrigacoes_emprestimos_repasses)s, %(captacoes)s, %(instrumentos_derivativos)s, %(outras_obrigacoes)s, %(passivo_circulante_exigivel_longo_prazo)s, %(resultado_exercicios_futuros)s, %(patrimonio_liquido)s, %(passivo_total)s)
# 2020-02-11 12:39:38,181 INFO sqlalchemy.engine.base.Engine ({'index': 2, 'nome_if': 'BB', 'co_if': 49906, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '06/2010', 'depositos_vista': '56.970.965', 'depositos_poupanca': '81.540.814', 'depositos_interfinanceiros': '10.137.854', 'depositos_prazo': '169.324.352', 'outros_depositos': '14.223.935', 'deposito_total': '332.197.920', 'obrigacoes_operacoes_compromissadas': '151.802.657', 'letras_credito_imobiliario': '0', 'letras_credito_agronegocio': '30.222', 'letras_financeiras': '0', 'obrigacoes_titulos_valores_mobiliarios_exterior': '6.975.093', 'outros_recursos_aceites_emissao_titulos': '0', 'recursos_aceites_emissao_titulos': '7.005.315', 'obrigacoes_emprestimos_repasses': '43.483.438', 'captacoes': '534.489.331', 'instrumentos_derivativos': '1.197.683', 'outras_obrigacoes': '108.624.671', 'passivo_circulante_exigivel_longo_prazo': '644.311.684', 'resultado_exercicios_futuros': '209.940', 'patrimonio_liquido': '39.386.785', 'passivo_total': '683.908.409'}, {'index': 3, 'nome_if': 'ITAU', 'co_if': 10069, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '06/2010', 'depositos_vista': '28.676.985', 'depositos_poupanca': '51.851.801', 'depositos_interfinanceiros': '4.967.687', 'depositos_prazo': '109.520.504', 'outros_depositos': '1.405.177', 'deposito_total': '196.422.154', 'obrigacoes_operacoes_compromissadas': '164.839.356', 'letras_credito_imobiliario': '5.895.352', 'letras_credito_agronegocio': '3.081.868', 'letras_financeiras': '515.473', 'obrigacoes_titulos_valores_mobiliarios_exterior': '6.282.819', 'outros_recursos_aceites_emissao_titulos': '1.022.148', 'recursos_aceites_emissao_titulos': '16.797.659', 'obrigacoes_emprestimos_repasses': '36.638.845', 'captacoes': '414.698.014', 'instrumentos_derivativos': '6.926.313', 'outras_obrigacoes': '152.108.297', 'passivo_circulante_exigivel_longo_prazo': '573.732.624', 'resultado_exercicios_futuros': '157.633', 'patrimonio_liquido': '56.027.775', 'passivo_total': '629.918.032'}, {'index': 4, 'nome_if': 'BRADESCO', 'co_if': 10045, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'OSASCO', 'uf': 'SP', 'dt_base': '06/2010', 'depositos_vista': '32.901.702', 'depositos_poupanca': '48.204.881', 'depositos_interfinanceiros': '821.067', 'depositos_prazo': '97.629.702', 'outros_depositos': '1.158.555', 'deposito_total': '180.715.906', 'obrigacoes_operacoes_compromissadas': '135.456.889', 'letras_credito_imobiliario': '202.228', 'letras_credito_agronegocio': '1.639.522', 'letras_financeiras': '3.432.015', 'obrigacoes_titulos_valores_mobiliarios_exterior': '5.717.846', 'outros_recursos_aceites_emissao_titulos': '1.737.751', 'recursos_aceites_emissao_titulos': '12.729.362', 'obrigacoes_emprestimos_repasses': '35.035.325', 'captacoes': '363.937.482', 'instrumentos_derivativos': '1.102.955', 'outras_obrigacoes': '85.871.490', 'passivo_circulante_exigivel_longo_prazo': '450.911.927', 'resultado_exercicios_futuros': '250.972', 'patrimonio_liquido': '44.459.353', 'passivo_total': '495.622.252'}, {'index': 5, 'nome_if': 'BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E SOCIAL', 'co_if': 33657248, 'tp_consolidado_bancario': 'b4', 'segmento': None, 'tp_consolidacao': 'I', 'tp_controle': 1, 'cidade': 'RIO DE JANEIRO', 'uf': 'RJ', 'dt_base': '06/2010', 'depositos_vista': '0', 'depositos_poupanca': '0', 'depositos_interfinanceiros': '0', 'depositos_prazo': '0', 'outros_depositos': '21.828.593', 'deposito_total': '21.828.593', 'obrigacoes_operacoes_compromissadas': '10.039.370', 'letras_credito_imobiliario': '0', 'letras_credito_agronegocio': '0', 'letras_financeiras': '0', 'obrigacoes_titulos_valores_mobiliarios_exterior': '0', 'outros_recursos_aceites_emissao_titulos': '0', 'recursos_aceites_emissao_titulos': '0', 'obrigacoes_em ...
# 2020-02-11 12:41:16,171 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:41:16,194 INFO sqlalchemy.engine.base.Engine SELECT * FROM prudenciais_passivo_relatorios_import
# 2020-02-11 12:41:16,195 INFO sqlalchemy.engine.base.Engine {}
# Registros importados com sucesso.

# %%
file_name = 'prudenciais_informacoes_capital_relatorios.csv'
df = pd.read_csv(os.path.join('bases', file_name), low_memory=False)

# remove unnamed columns
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 28', axis=1, inplace=True)

a_renomear = {
    'Instituição financeira':'nome_if',
    'Código':'co_if',
    'TCB':'tp_consolidado_bancario',
    'SR':'segmento',
    'TD':'tp_consolidacao',
    'TC':'tp_controle',
    'Cidade':'cidade',
    'UF':'uf',
    'Data':'dt_base',
    'Patrimônio de Referência para Comparação com o RWA':'capital_principal',
    'Unnamed: 10':'capital_complementar',
    'Unnamed: 11':'patrimonio_referencia_nivel_1',
    'Unnamed: 12':'capital_nivel_2',
    'Unnamed: 13':'patrimonio_referencia',
    'Ativos Ponderados pelo Risco (RWA)':'rwa_risco_credito',
    'Unnamed: 15':'rwa_cam',
    'Unnamed: 16':'rwa_com',
    'Unnamed: 17':'rwa_jur',
    'Unnamed: 18':'rwa_acs',
    'Unnamed: 19':'rwa_risco_mercado',
    'Unnamed: 20':'rwa_risco_operacional',
    'Unnamed: 21':'rwa_ativos_ponderados_risco',
    'Exposição Total (j)':'exposicao_total',
    'Índice de Capital Principal (k) = (a) / (i)':'ic_capital_principal',
    'Índice de Capital Nível I (l) = (c) / (i)':'ic_capital_nivel_1',
    'Índice de Basileia (m) = (e) / (i)':'ic_basileia',
    'Razão de Alavancagem (n) = (c) / (j)':'razao_alavancagem',
    'Índice de Imobilização (o)':'ic_imobilizacao',
}

# renomeia as colunas
df = df.rename(columns=a_renomear)

# remove informações que são consolidadas
df = df[df['co_if'].notnull()]

# convert just columns "a" and "b"
df['co_if'] = df['co_if'].astype(int)
df['tp_controle'] = df['tp_controle'].astype(int)

print(df.head())
print(df.dtypes)

# salva os registros no banco de dados
df.to_sql('prudenciais_informacoes_capital_relatorios_import', con=engine, if_exists='replace')

# executa para ver os resultados retornados que foram importados
df_banco = engine.execute("SELECT * FROM prudenciais_informacoes_capital_relatorios_import").fetchall()
print(len(df_banco))

print('Registros importados com sucesso.')
# Out:
#                                              nome_if     co_if  \
# 2                                               ITAU     10069
# 3                                                 BB     49906
# 4                                           BRADESCO     10045
# 5  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...  33657248
# 6                                          SANTANDER     30379
#
#   tp_consolidado_bancario segmento tp_consolidacao  tp_controle  \
# 2                      b1      NaN               C            2
# 3                      b1      NaN               C            1
# 4                      b1      NaN               C            2
# 5                      b4      NaN               I            1
# 6                      b1      NaN               C            3
#
#            cidade  uf  dt_base capital_principal  ...    rwa_acs  \
# 2       SAO PAULO  SP  06/2010               NaN  ...  3.245.400
# 3        BRASILIA  DF  06/2010               NaN  ...     31.072
# 4          OSASCO  SP  06/2010               NaN  ...    181.404
# 5  RIO DE JANEIRO  RJ  06/2010               NaN  ...          0
# 6       SAO PAULO  SP  06/2010               NaN  ...    433.609
#
#   rwa_risco_mercado rwa_risco_operacional rwa_ativos_ponderados_risco  \
# 2         8.814.498            24.201.690                 443.738.257
# 3           410.130            26.692.711                 422.292.641
# 4         1.226.370            15.252.325                 333.065.577
# 5         1.871.143             6.536.294                 326.983.609
# 6         6.399.861            13.090.138                 239.404.360
#
#   exposicao_total ic_capital_principal ic_capital_nivel_1 ic_basileia  \
# 2             NaN                  NA%                NA%      15,67%
# 3             NaN                  NA%                NA%      13,36%
# 4             NaN                  NA%                NA%      15,80%
# 5             NaN                  NA%                NA%      17,82%
# 6             NaN                  NA%                NA%      30,66%
#
#   razao_alavancagem ic_imobilizacao
# 2               NA%          38,95%
# 3               NA%          20,26%
# 4               NA%          48,03%
# 5               NA%           0,56%
# 6               NA%          39,78%
#
# [5 rows x 28 columns]
# nome_if                          object
# co_if                             int32
# tp_consolidado_bancario          object
# segmento                         object
# tp_consolidacao                  object
# tp_controle                       int32
# cidade                           object
# uf                               object
# dt_base                          object
# capital_principal                object
# capital_complementar             object
# patrimonio_referencia_nivel_1    object
# capital_nivel_2                  object
# patrimonio_referencia            object
# rwa_risco_credito                object
# rwa_cam                          object
# rwa_com                          object
# rwa_jur                          object
# rwa_acs                          object
# rwa_risco_mercado                object
# rwa_risco_operacional            object
# rwa_ativos_ponderados_risco      object
# exposicao_total                  object
# ic_capital_principal             object
# ic_capital_nivel_1               object
# ic_basileia                      object
# razao_alavancagem                object
# ic_imobilizacao                  object
# dtype: object
# 2020-02-11 12:54:52,896 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-02-11 12:54:52,898 INFO sqlalchemy.engine.base.Engine {'name': 'prudenciais_informacoes_capital_relatorios_import'}
# 2020-02-11 12:54:52,912 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE prudenciais_informacoes_capital_relatorios_import (
# 	index BIGINT,
# 	nome_if TEXT,
# 	co_if INTEGER,
# 	tp_consolidado_bancario TEXT,
# 	segmento TEXT,
# 	tp_consolidacao TEXT,
# 	tp_controle INTEGER,
# 	cidade TEXT,
# 	uf TEXT,
# 	dt_base TEXT,
# 	capital_principal TEXT,
# 	capital_complementar TEXT,
# 	patrimonio_referencia_nivel_1 TEXT,
# 	capital_nivel_2 TEXT,
# 	patrimonio_referencia TEXT,
# 	rwa_risco_credito TEXT,
# 	rwa_cam TEXT,
# 	rwa_com TEXT,
# 	rwa_jur TEXT,
# 	rwa_acs TEXT,
# 	rwa_risco_mercado TEXT,
# 	rwa_risco_operacional TEXT,
# 	rwa_ativos_ponderados_risco TEXT,
# 	exposicao_total TEXT,
# 	ic_capital_principal TEXT,
# 	ic_capital_nivel_1 TEXT,
# 	ic_basileia TEXT,
# 	razao_alavancagem TEXT,
# 	ic_imobilizacao TEXT
# )
#
#
# 2020-02-11 12:54:52,914 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:54:52,929 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:54:52,935 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_prudenciais_informacoes_capital_relatorios_import_index ON prudenciais_informacoes_capital_relatorios_import (index)
# 2020-02-11 12:54:52,937 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 12:54:52,943 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:54:53,054 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-02-11 12:54:55,144 INFO sqlalchemy.engine.base.Engine INSERT INTO prudenciais_informacoes_capital_relatorios_import (index, nome_if, co_if, tp_consolidado_bancario, segmento, tp_consolidacao, tp_controle, cidade, uf, dt_base, capital_principal, capital_complementar, patrimonio_referencia_nivel_1, capital_nivel_2, patrimonio_referencia, rwa_risco_credito, rwa_cam, rwa_com, rwa_jur, rwa_acs, rwa_risco_mercado, rwa_risco_operacional, rwa_ativos_ponderados_risco, exposicao_total, ic_capital_principal, ic_capital_nivel_1, ic_basileia, razao_alavancagem, ic_imobilizacao) VALUES (%(index)s, %(nome_if)s, %(co_if)s, %(tp_consolidado_bancario)s, %(segmento)s, %(tp_consolidacao)s, %(tp_controle)s, %(cidade)s, %(uf)s, %(dt_base)s, %(capital_principal)s, %(capital_complementar)s, %(patrimonio_referencia_nivel_1)s, %(capital_nivel_2)s, %(patrimonio_referencia)s, %(rwa_risco_credito)s, %(rwa_cam)s, %(rwa_com)s, %(rwa_jur)s, %(rwa_acs)s, %(rwa_risco_mercado)s, %(rwa_risco_operacional)s, %(rwa_ativos_ponderados_risco)s, %(exposicao_total)s, %(ic_capital_principal)s, %(ic_capital_nivel_1)s, %(ic_basileia)s, %(razao_alavancagem)s, %(ic_imobilizacao)s)
# 2020-02-11 12:54:55,145 INFO sqlalchemy.engine.base.Engine ({'index': 2, 'nome_if': 'ITAU', 'co_if': 10069, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '06/2010', 'capital_principal': None, 'capital_complementar': None, 'patrimonio_referencia_nivel_1': '54.182.613', 'capital_nivel_2': '15.357.919', 'patrimonio_referencia': '69.520.662', 'rwa_risco_credito': '410.722.069', 'rwa_cam': '0', 'rwa_com': '911.459', 'rwa_jur': '4.657.640', 'rwa_acs': '3.245.400', 'rwa_risco_mercado': '8.814.498', 'rwa_risco_operacional': '24.201.690', 'rwa_ativos_ponderados_risco': '443.738.257', 'exposicao_total': None, 'ic_capital_principal': 'NA%', 'ic_capital_nivel_1': 'NA%', 'ic_basileia': '15,67%', 'razao_alavancagem': 'NA%', 'ic_imobilizacao': '38,95%'}, {'index': 3, 'nome_if': 'BB', 'co_if': 49906, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '06/2010', 'capital_principal': None, 'capital_complementar': None, 'patrimonio_referencia_nivel_1': '41.551.720', 'capital_nivel_2': '18.801.179', 'patrimonio_referencia': '56.438.421', 'rwa_risco_credito': '395.189.800', 'rwa_cam': '0', 'rwa_com': '22.682', 'rwa_jur': '356.377', 'rwa_acs': '31.072', 'rwa_risco_mercado': '410.130', 'rwa_risco_operacional': '26.692.711', 'rwa_ativos_ponderados_risco': '422.292.641', 'exposicao_total': None, 'ic_capital_principal': 'NA%', 'ic_capital_nivel_1': 'NA%', 'ic_basileia': '13,36%', 'razao_alavancagem': 'NA%', 'ic_imobilizacao': '20,26%'}, {'index': 4, 'nome_if': 'BRADESCO', 'co_if': 10045, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'OSASCO', 'uf': 'SP', 'dt_base': '06/2010', 'capital_principal': None, 'capital_complementar': None, 'patrimonio_referencia_nivel_1': '45.853.225', 'capital_nivel_2': '6.855.920', 'patrimonio_referencia': '52.619.552', 'rwa_risco_credito': '316.586.882', 'rwa_cam': '0', 'rwa_com': '7.517', 'rwa_jur': '1.037.450', 'rwa_acs': '181.404', 'rwa_risco_mercado': '1.226.370', 'rwa_risco_operacional': '15.252.325', 'rwa_ativos_ponderados_risco': '333.065.577', 'exposicao_total': None, 'ic_capital_principal': 'NA%', 'ic_capital_nivel_1': 'NA%', 'ic_basileia': '15,80%', 'razao_alavancagem': 'NA%', 'ic_imobilizacao': '48,03%'}, {'index': 5, 'nome_if': 'BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E SOCIAL', 'co_if': 33657248, 'tp_consolidado_bancario': 'b4', 'segmento': None, 'tp_consolidacao': 'I', 'tp_controle': 1, 'cidade': 'RIO DE JANEIRO', 'uf': 'RJ', 'dt_base': '06/2010', 'capital_principal': None, 'capital_complementar': None, 'patrimonio_referencia_nivel_1': '34.658.206', 'capital_nivel_2': '25.624.882', 'patrimonio_referencia': '58.276.298', 'rwa_risco_credito': '318.576.172', 'rwa_cam': '0', 'rwa_com': '0', 'rwa_jur': '1.871.143', 'rwa_acs': '0', 'rwa_risco_mercado': '1.871.143', 'rwa_risco_operacional': '6.536.294', 'rwa_ativos_ponderados_risco': '326.983.609', 'exposicao_total': None, 'ic_capital_principal': 'NA%', 'ic_capital_nivel_1': 'NA%', 'ic_basileia': '17,82%', 'razao_alavancagem': 'NA%', 'ic_imobilizacao': '0,56%'}, {'index': 6, 'nome_if': 'SANTANDER', 'co_if': 30379, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 3, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '06/2010', 'capital_principal': None, 'capital_complementar': None, 'patrimonio_referencia_nivel_1': '65.193.490', 'capital_nivel_2': '8.211.323', 'patrimonio_referencia': '73.402.718', 'rwa_risco_credito': '219.914.361', 'rwa_cam': '0', 'rwa_com': '13.618', 'rwa_jur': '5.952.634', 'rwa_acs': '433.609', 'rwa_risco_mercado': '6.399.861', 'rwa_risco_operacional': '13.090.138', 'rwa_ativos_ponderados_risco': '239.404.360', 'exposicao_total': None, 'ic_capital_principal': 'NA%', 'ic_capital_nivel_1': 'NA%', 'ic_basileia': '30,66%', 'razao_alavancagem': 'NA%', 'ic_imobilizacao': '39,78%'}, ...
# 2020-02-11 12:56:25,546 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 12:56:25,563 INFO sqlalchemy.engine.base.Engine SELECT * FROM prudenciais_informacoes_capital_relatorios_import
# 2020-02-11 12:56:25,566 INFO sqlalchemy.engine.base.Engine {}
# Registros importados com sucesso.

# %%
file_name = 'prudenciais_demonstracao_resultado_relatorios.csv'
df = pd.read_csv(os.path.join('bases', file_name), low_memory=False)

# remove unnamed columns
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 39', axis=1, inplace=True)

a_renomear = {
    'Instituição financeira':'nome_if',
    'Código':'co_if',
    'TCB':'tp_consolidado_bancario',
    'SR':'segmento',
    'TD':'tp_consolidacao',
    'TC':'tp_controle',
    'Cidade':'cidade',
    'UF':'uf',
    'Data':'dt_base',
    'Resultado de Intermediação Financeira':'rendas_op_credito',
    'Unnamed: 10':'rendas_op_arrendamento_mercantil',
    'Unnamed: 11':'Rendas de Operações com TVM (a3)',
    'Unnamed: 12':'rendas_op_derivativos',
    'Unnamed: 13':'resultado_op_cambio',
    'Unnamed: 14':'rendas_aplicacoes_compulsorias',
    'Unnamed: 15':'receitas_intermediacao_financeira',
    'Unnamed: 16':'despesas_captacao',
    'Unnamed: 17':'despesas_obrigacoes_emprestimos_repasses',
    'Unnamed: 18':'despesas_operacoes_arrendamento_mercantil',
    'Unnamed: 19':'resultado_op_cambio',
    'Unnamed: 20':'resultado_provisao_credito_dificil_liquidacao',
    'Unnamed: 21':'despesas_intermediacao_financeira',
    'Unnamed: 22':'resultado_intermediacao_financeira',
    'Outras Receitas/Despesas Operacionais':'rendas_prestacao_servicos',
    'Unnamed: 24':'rendas_tarifas_bancarias',
    'Unnamed: 25':'despesas_pessoal',
    'Unnamed: 26':'despesas_administrativas',
    'Unnamed: 27':'despesas_tributarias',
    'Unnamed: 28':'resultado_participacoes',
    'Unnamed: 29':'outras_receitas_operacionais',
    'Unnamed: 30':'outras_despesas_operacionais',
    'Unnamed: 31':'outras_receitas_despesas_operacionais',
    'Resultado Operacional (e) = (c) + (d)':'resultado_operacional',
    'Resultado Não Operacional (f)':'resultado_nao_operacional',
    'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)':'resultado_antes_tributacao_lucro_participacao',
    'Imposto de Renda e Contribuição Social (h)':'imposto_renda_contribuicao_social',
    'Participação nos Lucros (i)':'participacao_lucros',
    'Lucro Líquido (j) = (g) + (h) + (i)':'lucro_liquido',
    'Juros Sobre Capital Próprio (k)':'juros_sobre_capital_proprio',
    'Juros Sobre Capital Social de Cooperativas (k)':'juros_sobre_capital_cooperativas'
}

# renomeia as colunas
df = df.rename(columns=a_renomear)

# remove informações que são consolidadas
df = df[df['co_if'].notnull()]

# convert just columns "a" and "b"
df['co_if'] = df['co_if'].astype(int)
df['tp_controle'] = df['tp_controle'].astype(int)

print(df.head())
print(df.dtypes)

# salva os registros no banco de dados
df.to_sql('prudenciais_demonstracao_resultado_relatorios_import', con=engine, if_exists='replace')

# executa para ver os resultados retornados que foram importados
df_banco = engine.execute("SELECT * FROM prudenciais_demonstracao_resultado_relatorios_import").fetchall()
print(len(df_banco))

print('Registros importados com sucesso.')
# Out:
#                    nome_if   co_if tp_consolidado_bancario segmento  \
# 2                     ITAU   10069                      b1      NaN
# 3                       BB   49906                      b1      NaN
# 4                 BRADESCO   10045                      b1      NaN
# 5                SANTANDER   30379                      b1      NaN
# 6  CAIXA ECONOMICA FEDERAL  360305                      b1      NaN
#
#   tp_consolidacao  tp_controle     cidade  uf  dt_base rendas_op_credito  ...  \
# 2               C            2  SAO PAULO  SP  06/2010        23.830.964  ...
# 3               C            1   BRASILIA  DF  06/2010        22.312.346  ...
# 4               C            2     OSASCO  SP  06/2010        17.550.695  ...
# 5               C            3  SAO PAULO  SP  06/2010        13.770.970  ...
# 6               I            1   BRASILIA  DF  06/2010         8.815.960  ...
#
#   outras_despesas_operacionais outras_receitas_despesas_operacionais  \
# 2                   -6.335.088                            -5.149.802
# 3                   -2.910.743                            -3.039.197
# 4                   -3.556.649                            -4.893.589
# 5                   -4.985.356                            -7.241.129
# 6                   -3.818.284                            -4.492.500
#
#   resultado_operacional resultado_nao_operacional  \
# 2             7.965.546                   609.420
# 3             7.840.086                   269.807
# 4             5.238.069                  -201.774
# 5             1.852.489                   938.110
# 6             1.606.027                   -70.034
#
#   resultado_antes_tributacao_lucro_participacao  \
# 2                                     8.574.966
# 3                                     8.109.893
# 4                                     5.036.295
# 5                                     2.790.600
# 6                                     1.535.993
#
#   imposto_renda_contribuicao_social participacao_lucros lucro_liquido  \
# 2                        -1.119.036          -1.015.384     6.440.546
# 3                        -2.322.889            -655.819     5.131.185
# 4                          -519.001                   0     4.517.294
# 5                          -226.016            -516.323     2.048.261
# 6                           332.886            -201.195     1.667.684
#
#   juros_sobre_capital_proprio juros_sobre_capital_cooperativas
# 2                  -1.890.804                              NaN
# 3                  -1.043.527                              NaN
# 4                  -1.257.960                              NaN
# 5                    -800.000                              NaN
# 6                    -378.024                              NaN
#
# [5 rows x 40 columns]
# nome_if                                          object
# co_if                                             int32
# tp_consolidado_bancario                          object
# segmento                                         object
# tp_consolidacao                                  object
# tp_controle                                       int32
# cidade                                           object
# uf                                               object
# dt_base                                          object
# rendas_op_credito                                object
# rendas_op_arrendamento_mercantil                 object
# Rendas de Operações com TVM (a3)                 object
# rendas_op_derivativos                            object
# resultado_op_cambio                              object
# rendas_aplicacoes_compulsorias                   object
# receitas_intermediacao_financeira                object
# despesas_captacao                                object
# despesas_obrigacoes_emprestimos_repasses         object
# despesas_operacoes_arrendamento_mercantil        object
# resultado_op_cambio                              object
# resultado_provisao_credito_dificil_liquidacao    object
# despesas_intermediacao_financeira                object
# resultado_intermediacao_financeira               object
# rendas_prestacao_servicos                        object
# rendas_tarifas_bancarias                         object
# despesas_pessoal                                 object
# despesas_administrativas                         object
# despesas_tributarias                             object
# resultado_participacoes                          object
# outras_receitas_operacionais                     object
# outras_despesas_operacionais                     object
# outras_receitas_despesas_operacionais            object
# resultado_operacional                            object
# resultado_nao_operacional                        object
# resultado_antes_tributacao_lucro_participacao    object
# imposto_renda_contribuicao_social                object
# participacao_lucros                              object
# lucro_liquido                                    object
# juros_sobre_capital_proprio                      object
# juros_sobre_capital_cooperativas                 object
# dtype: object
# 2020-02-11 13:18:38,482 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-02-11 13:18:38,484 INFO sqlalchemy.engine.base.Engine {'name': 'prudenciais_demonstracao_resultado_relatorios_import'}
# 2020-02-11 13:18:38,494 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE prudenciais_demonstracao_resultado_relatorios_import (
# 	index BIGINT,
# 	nome_if TEXT,
# 	co_if INTEGER,
# 	tp_consolidado_bancario TEXT,
# 	segmento TEXT,
# 	tp_consolidacao TEXT,
# 	tp_controle INTEGER,
# 	cidade TEXT,
# 	uf TEXT,
# 	dt_base TEXT,
# 	rendas_op_credito TEXT,
# 	rendas_op_arrendamento_mercantil TEXT,
# 	"Rendas de Operações com TVM (a3)" TEXT,
# 	rendas_op_derivativos TEXT,
# 	resultado_op_cambio TEXT,
# 	rendas_aplicacoes_compulsorias TEXT,
# 	receitas_intermediacao_financeira TEXT,
# 	despesas_captacao TEXT,
# 	despesas_obrigacoes_emprestimos_repasses TEXT,
# 	despesas_operacoes_arrendamento_mercantil TEXT,
# 	resultado_provisao_credito_dificil_liquidacao TEXT,
# 	despesas_intermediacao_financeira TEXT,
# 	resultado_intermediacao_financeira TEXT,
# 	rendas_prestacao_servicos TEXT,
# 	rendas_tarifas_bancarias TEXT,
# 	despesas_pessoal TEXT,
# 	despesas_administrativas TEXT,
# 	despesas_tributarias TEXT,
# 	resultado_participacoes TEXT,
# 	outras_receitas_operacionais TEXT,
# 	outras_despesas_operacionais TEXT,
# 	outras_receitas_despesas_operacionais TEXT,
# 	resultado_operacional TEXT,
# 	resultado_nao_operacional TEXT,
# 	resultado_antes_tributacao_lucro_participacao TEXT,
# 	imposto_renda_contribuicao_social TEXT,
# 	participacao_lucros TEXT,
# 	lucro_liquido TEXT,
# 	juros_sobre_capital_proprio TEXT,
# 	juros_sobre_capital_cooperativas TEXT
# )
#
#
# 2020-02-11 13:18:38,496 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 13:18:38,507 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 13:18:38,527 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_prudenciais_demonstracao_resultado_relatorios_import_index ON prudenciais_demonstracao_resultado_relatorios_import (index)
# 2020-02-11 13:18:38,531 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 13:18:38,539 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 13:18:38,726 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-02-11 13:18:41,642 INFO sqlalchemy.engine.base.Engine INSERT INTO prudenciais_demonstracao_resultado_relatorios_import (index, nome_if, co_if, tp_consolidado_bancario, segmento, tp_consolidacao, tp_controle, cidade, uf, dt_base, rendas_op_credito, rendas_op_arrendamento_mercantil, "Rendas de Operações com TVM (a3)", rendas_op_derivativos, resultado_op_cambio, rendas_aplicacoes_compulsorias, receitas_intermediacao_financeira, despesas_captacao, despesas_obrigacoes_emprestimos_repasses, despesas_operacoes_arrendamento_mercantil, resultado_provisao_credito_dificil_liquidacao, despesas_intermediacao_financeira, resultado_intermediacao_financeira, rendas_prestacao_servicos, rendas_tarifas_bancarias, despesas_pessoal, despesas_administrativas, despesas_tributarias, resultado_participacoes, outras_receitas_operacionais, outras_despesas_operacionais, outras_receitas_despesas_operacionais, resultado_operacional, resultado_nao_operacional, resultado_antes_tributacao_lucro_participacao, imposto_renda_contribuicao_social, participacao_lucros, lucro_liquido, juros_sobre_capital_proprio, juros_sobre_capital_cooperativas) VALUES (%(index)s, %(nome_if)s, %(co_if)s, %(tp_consolidado_bancario)s, %(segmento)s, %(tp_consolidacao)s, %(tp_controle)s, %(cidade)s, %(uf)s, %(dt_base)s, %(rendas_op_credito)s, %(rendas_op_arrendamento_mercantil)s, %(Rendas de Operações com TVM (a3))s, %(rendas_op_derivativos)s, %(resultado_op_cambio)s, %(rendas_aplicacoes_compulsorias)s, %(receitas_intermediacao_financeira)s, %(despesas_captacao)s, %(despesas_obrigacoes_emprestimos_repasses)s, %(despesas_operacoes_arrendamento_mercantil)s, %(resultado_provisao_credito_dificil_liquidacao)s, %(despesas_intermediacao_financeira)s, %(resultado_intermediacao_financeira)s, %(rendas_prestacao_servicos)s, %(rendas_tarifas_bancarias)s, %(despesas_pessoal)s, %(despesas_administrativas)s, %(despesas_tributarias)s, %(resultado_participacoes)s, %(outras_receitas_operacionais)s, %(outras_despesas_operacionais)s, %(outras_receitas_despesas_operacionais)s, %(resultado_operacional)s, %(resultado_nao_operacional)s, %(resultado_antes_tributacao_lucro_participacao)s, %(imposto_renda_contribuicao_social)s, %(participacao_lucros)s, %(lucro_liquido)s, %(juros_sobre_capital_proprio)s, %(juros_sobre_capital_cooperativas)s)
# 2020-02-11 13:18:41,644 INFO sqlalchemy.engine.base.Engine ({'index': 2, 'nome_if': 'ITAU', 'co_if': 10069, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '06/2010', 'rendas_op_credito': '23.830.964', 'rendas_op_arrendamento_mercantil': '13.078.059', 'Rendas de Opera\xe7\xf5es com TVM (a3)': '7.934.295', 'rendas_op_derivativos': '148.301', 'resultado_op_cambio': '0', 'rendas_aplicacoes_compulsorias': '1.231.752', 'receitas_intermediacao_financeira': '47.470.923', 'despesas_captacao': '-14.652.061', 'despesas_obrigacoes_emprestimos_repasses': '-1.557.774', 'despesas_operacoes_arrendamento_mercantil': '-10.350.804', 'resultado_provisao_credito_dificil_liquidacao': '-7.794.935', 'despesas_intermediacao_financeira': '-34.355.575', 'resultado_intermediacao_financeira': '13.115.348', 'rendas_prestacao_servicos': '4.756.026', 'rendas_tarifas_bancarias': '1.536.923', 'despesas_pessoal': '-4.507.501', 'despesas_administrativas': '-6.522.501', 'despesas_tributarias': '-1.269.478', 'resultado_participacoes': '1.530.155', 'outras_receitas_operacionais': '5.661.662', 'outras_despesas_operacionais': '-6.335.088', 'outras_receitas_despesas_operacionais': '-5.149.802', 'resultado_operacional': '7.965.546', 'resultado_nao_operacional': '609.420', 'resultado_antes_tributacao_lucro_participacao': '8.574.966', 'imposto_renda_contribuicao_social': '-1.119.036', 'participacao_lucros': '-1.015.384', 'lucro_liquido': '6.440.546', 'juros_sobre_capital_proprio': '-1.890.804', 'juros_sobre_capital_cooperativas': None}, {'index': 3, 'nome_if': 'BB', 'co_if': 49906, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '06/2010', 'rendas_op_credito': '22.312.346', 'rendas_op_arrendamento_mercantil': '917.121', 'Rendas de Opera\xe7\xf5es com TVM (a3)': '9.855.018', 'rendas_op_derivativos': '123.211', 'resultado_op_cambio': '-3.893', 'rendas_aplicacoes_compulsorias': '1.145.954', 'receitas_intermediacao_financeira': '34.353.650', 'despesas_captacao': '-15.992.077', 'despesas_obrigacoes_emprestimos_repasses': '-1.761.101', 'despesas_operacoes_arrendamento_mercantil': '-667.428', 'resultado_provisao_credito_dificil_liquidacao': '-5.049.868', 'despesas_intermediacao_financeira': '-23.474.367', 'resultado_intermediacao_financeira': '10.879.283', 'rendas_prestacao_servicos': '4.657.277', 'rendas_tarifas_bancarias': '1.816.170', 'despesas_pessoal': '-5.776.589', 'despesas_administrativas': '-5.162.483', 'despesas_tributarias': '-1.435.707', 'resultado_participacoes': '1.057.189', 'outras_receitas_operacionais': '4.715.690', 'outras_despesas_operacionais': '-2.910.743', 'outras_receitas_despesas_operacionais': '-3.039.197', 'resultado_operacional': '7.840.086', 'resultado_nao_operacional': '269.807', 'resultado_antes_tributacao_lucro_participacao': '8.109.893', 'imposto_renda_contribuicao_social': '-2.322.889', 'participacao_lucros': '-655.819', 'lucro_liquido': '5.131.185', 'juros_sobre_capital_proprio': '-1.043.527', 'juros_sobre_capital_cooperativas': None}, {'index': 4, 'nome_if': 'BRADESCO', 'co_if': 10045, 'tp_consolidado_bancario': 'b1', 'segmento': None, 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'OSASCO', 'uf': 'SP', 'dt_base': '06/2010', 'rendas_op_credito': '17.550.695', 'rendas_op_arrendamento_mercantil': '7.392.739', 'Rendas de Opera\xe7\xf5es com TVM (a3)': '7.265.751', 'rendas_op_derivativos': '255.162', 'resultado_op_cambio': '0', 'rendas_aplicacoes_compulsorias': '945.872', 'receitas_intermediacao_financeira': '33.920.713', 'despesas_captacao': '-12.052.618', 'despesas_obrigacoes_emprestimos_repasses': '-1.061.867', 'despesas_operacoes_arrendamento_mercantil': '-6.196.023', 'resultado_provisao_credito_dificil_liquidacao': '-4.478.547', 'despesas_intermediacao_financeira': '-23.789.056', 'resultado_intermediacao_financeira': '10.131.658', 'rendas_prestacao_servicos': ...
# 2020-02-11 13:18:41,647 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-b0ff304557f0> in <module>()
#      63
#      64 # salva os registros no banco de dados
# ---> 65 df.to_sql('prudenciais_demonstracao_resultado_relatorios_import', con=engine, if_exists='replace')
#      66
#      67 # executa para ver os resultados retornados que foram importados
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1414                 )
#    1415             else:
# -> 1416                 util.reraise(*exc_info)
#    1417
#    1418         finally:
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# C:\WinPython\python-3.6.5.amd64\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     681             extras.execute_batch(cursor, statement, parameters)
#     682         else:
# --> 683             cursor.executemany(statement, parameters)
#     684
#     685     @util.memoized_instancemethod
#
# KeyError: 'Rendas de Operações com TVM (a3'

# %%
file_name = 'prudenciais_segmentacao_relatorios.csv'
df = pd.read_csv(os.path.join('bases', file_name), low_memory=False)

# remove unnamed columns
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 15', axis=1, inplace=True)

a_renomear = {
    'Instituição financeira':'nome_if',
    'Código':'co_if',
    'TCB':'tp_consolidado_bancario',
    'SR':'segmento',
    'TD':'tp_consolidacao',
    'TC':'tp_controle',
    'Cidade':'cidade',
    'UF':'uf',
    'Data':'dt_base',
    'Instituição Sujeita à Apuração da Exposição Total':'ic_apuracao_exposicao_total',
    'Instituição Sujeita à Apuração do Patrimônio de Referência':'ic_apuracao_patrimonio_referencia',
    'Instituição Utiliza Metodologia Simplificada':'ic_metodologia_simplificada',
    'Exposição Total ou Ativo Total (R$ mil)':'exposicao_total',
    'Total de Ativos Consolidados no Exterior (US$ mil)':'total_ativos_consolidado_exterior',
    'Data da Última Alteração de Segmento':'dt_ultima_alteracao_segmento'
}

# renomeia as colunas
df = df.rename(columns=a_renomear)

# remove informações que são consolidadas
df = df[df['co_if'].notnull()]

# convert just columns "a" and "b"
df['co_if'] = df['co_if'].astype(int)
df['tp_controle'] = df['tp_controle'].astype(int)


print(df.head())
print(df.dtypes)

# salva os registros no banco de dados
df.to_sql('prudenciais_segmentacao_relatorios_import', con=engine, if_exists='replace')

# executa para ver os resultados retornados que foram importados
df_banco = engine.execute("SELECT * FROM prudenciais_segmentacao_relatorios_import").fetchall()
print(len(df_banco))

print('Registros importados com sucesso.')
# Out:
#                     nome_if       co_if tp_consolidado_bancario  \
# 0     BRADESCO - PRUDENCIAL  1000080075                      b1
# 1         ITAU - PRUDENCIAL  1000080099                      b1
# 2    SANTANDER - PRUDENCIAL  1000080185                      b1
# 3           BB - PRUDENCIAL  1000080329                      b1
# 4  BTG PACTUAL - PRUDENCIAL  1000080336                      b1
#
#   tp_consolidacao  tp_controle          cidade  uf  dt_base  \
# 0               C            2          OSASCO  SP  03/2017
# 1               C            2       SAO PAULO  SP  03/2017
# 2               C            3       SAO PAULO  SP  03/2017
# 3               C            1        BRASILIA  DF  03/2017
# 4               C            2  RIO DE JANEIRO  RJ  03/2017
#
#   ic_apuracao_exposicao_total ic_apuracao_patrimonio_referencia  \
# 0                         Sim                               Sim
# 1                         Sim                               Sim
# 2                         Sim                               Sim
# 3                         Sim                               Sim
# 4                         Sim                               Sim
#
#   ic_metodologia_simplificada exposicao_total  \
# 0                         Não   1.083.956.147
# 1                         Não   1.302.425.229
# 2                         Não     619.863.093
# 3                         Não   1.132.202.129
# 4                         Não     126.324.730
#
#   total_ativos_consolidado_exterior dt_ultima_alteracao_segmento segmento
# 0                        32.599.528                      01/2017       S1
# 1                       135.574.502                      01/2017       S1
# 2                        28.483.441                      01/2017       S1
# 3                        48.563.981                      01/2017       S1
# 4                        11.370.368                      01/2017       S1
# nome_if                              object
# co_if                                 int32
# tp_consolidado_bancario              object
# tp_consolidacao                      object
# tp_controle                           int32
# cidade                               object
# uf                                   object
# dt_base                              object
# ic_apuracao_exposicao_total          object
# ic_apuracao_patrimonio_referencia    object
# ic_metodologia_simplificada          object
# exposicao_total                      object
# total_ativos_consolidado_exterior    object
# dt_ultima_alteracao_segmento         object
# segmento                             object
# dtype: object
# 2020-02-11 13:24:26,316 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-02-11 13:24:26,318 INFO sqlalchemy.engine.base.Engine {'name': 'prudenciais_segmentacao_relatorios_import'}
# 2020-02-11 13:24:26,328 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE prudenciais_segmentacao_relatorios_import (
# 	index BIGINT,
# 	nome_if TEXT,
# 	co_if INTEGER,
# 	tp_consolidado_bancario TEXT,
# 	tp_consolidacao TEXT,
# 	tp_controle INTEGER,
# 	cidade TEXT,
# 	uf TEXT,
# 	dt_base TEXT,
# 	ic_apuracao_exposicao_total TEXT,
# 	ic_apuracao_patrimonio_referencia TEXT,
# 	ic_metodologia_simplificada TEXT,
# 	exposicao_total TEXT,
# 	total_ativos_consolidado_exterior TEXT,
# 	dt_ultima_alteracao_segmento TEXT,
# 	segmento TEXT
# )
#
#
# 2020-02-11 13:24:26,330 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 13:24:26,340 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 13:24:26,357 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_prudenciais_segmentacao_relatorios_import_index ON prudenciais_segmentacao_relatorios_import (index)
# 2020-02-11 13:24:26,359 INFO sqlalchemy.engine.base.Engine {}
# 2020-02-11 13:24:26,367 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 13:24:26,398 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-02-11 13:24:26,951 INFO sqlalchemy.engine.base.Engine INSERT INTO prudenciais_segmentacao_relatorios_import (index, nome_if, co_if, tp_consolidado_bancario, tp_consolidacao, tp_controle, cidade, uf, dt_base, ic_apuracao_exposicao_total, ic_apuracao_patrimonio_referencia, ic_metodologia_simplificada, exposicao_total, total_ativos_consolidado_exterior, dt_ultima_alteracao_segmento, segmento) VALUES (%(index)s, %(nome_if)s, %(co_if)s, %(tp_consolidado_bancario)s, %(tp_consolidacao)s, %(tp_controle)s, %(cidade)s, %(uf)s, %(dt_base)s, %(ic_apuracao_exposicao_total)s, %(ic_apuracao_patrimonio_referencia)s, %(ic_metodologia_simplificada)s, %(exposicao_total)s, %(total_ativos_consolidado_exterior)s, %(dt_ultima_alteracao_segmento)s, %(segmento)s)
# 2020-02-11 13:24:26,952 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'nome_if': 'BRADESCO - PRUDENCIAL', 'co_if': 1000080075, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'OSASCO', 'uf': 'SP', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '1.083.956.147', 'total_ativos_consolidado_exterior': '32.599.528', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S1'}, {'index': 1, 'nome_if': 'ITAU - PRUDENCIAL', 'co_if': 1000080099, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '1.302.425.229', 'total_ativos_consolidado_exterior': '135.574.502', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S1'}, {'index': 2, 'nome_if': 'SANTANDER - PRUDENCIAL', 'co_if': 1000080185, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 3, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '619.863.093', 'total_ativos_consolidado_exterior': '28.483.441', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S1'}, {'index': 3, 'nome_if': 'BB - PRUDENCIAL', 'co_if': 1000080329, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '1.132.202.129', 'total_ativos_consolidado_exterior': '48.563.981', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S1'}, {'index': 4, 'nome_if': 'BTG PACTUAL - PRUDENCIAL', 'co_if': 1000080336, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'RIO DE JANEIRO', 'uf': 'RJ', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '126.324.730', 'total_ativos_consolidado_exterior': '11.370.368', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S1'}, {'index': 5, 'nome_if': 'CAIXA ECONÔMICA FEDERAL - PRUDENCIAL', 'co_if': 1000080738, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'BRASILIA', 'uf': 'DF', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '1.374.513.248', 'total_ativos_consolidado_exterior': 'NI', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S1'}, {'index': 6, 'nome_if': 'SAFRA - PRUDENCIAL', 'co_if': 1000080109, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 2, 'cidade': 'SAO PAULO', 'uf': 'SP', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '169.754.678', 'total_ativos_consolidado_exterior': '5.324.013', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S2'}, {'index': 7, 'nome_if': 'BANRISUL - PRUDENCIAL', 'co_if': 1000080154, 'tp_consolidado_bancario': 'b1', 'tp_consolidacao': 'C', 'tp_controle': 1, 'cidade': 'PORTO ALEGRE', 'uf': 'RS', 'dt_base': '03/2017', 'ic_apuracao_exposicao_total': 'Sim', 'ic_apuracao_patrimonio_referencia': 'Sim', 'ic_metodologia_simplificada': 'Não', 'exposicao_total': '71.881.763', 'total_ativos_consolidado_exterior': '251.044', 'dt_ultima_alteracao_segmento': '01/2017', 'segmento': 'S2'}  ... displaying 10 of 15081 total bound parameter sets ...  {'index': 15473, 'nome_if': 'TANGER SCD - PRUDENCIAL', 'co_if': 1000084992, 'tp_consolidado_bancario': 'n1', 'tp_consolidaca ...
# 2020-02-11 13:24:49,636 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-02-11 13:24:49,643 INFO sqlalchemy.engine.base.Engine SELECT * FROM prudenciais_segmentacao_relatorios_import
# 2020-02-11 13:24:49,646 INFO sqlalchemy.engine.base.Engine {}
# Registros importados com sucesso.
